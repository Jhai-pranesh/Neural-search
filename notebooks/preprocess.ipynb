# %%
import pandas as pd

# %%
df1 = pd.read_parquet('../data/shopping_queries_dataset_examples.parquet')
df2 = pd.read_parquet('../data/shopping_queries_dataset_products.parquet')

# %%
df1.head()
# Out:
#    example_id           query  query_id  product_id product_locale esci_label  \
# 0           0   revent 80 cfm         0  B000MOO21W             us          I
# 1           1   revent 80 cfm         0  B07X3Y6B1V             us          E
# 2           2   revent 80 cfm         0  B07WDM7MQQ             us          E
# 3           3   revent 80 cfm         0  B07RH6Z8KW             us          E
# 4           4   revent 80 cfm         0  B07QJ7WYFQ             us          E
#
#    small_version  large_version  split
# 0              0              1  train
# 1              0              1  train
# 2              0              1  train
# 3              0              1  train
# 4              0              1  train

# %%
df2.dropna(axis=0,how='any',inplace = True)

# %%
df2.count()
# Out:
# product_id              596407
# product_title           596407
# product_description     596407
# product_bullet_point    596407
# product_brand           596407
# product_color           596407
# product_locale          596407
# dtype: int64

# %%
ls = []
for i in range(10):
    ls.append(df2[i-1:i])

# %%
ls[1]['product_description']
# Out:
# 0    Esta playera con el logo de la marca Carrier d...
# Name: product_description, dtype: object
